# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
import pickle

# %%
#Data Collection and Analysis

insurance_dataset=pd.read_csv('insurance.csv')

# %%
insurance_dataset
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_dataset.shape
# Out:
# (1338, 7)

# %%
insurance_dataset.head(7)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960

# %%
#Getting information about dataset
insurance_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# Categorical Features:
#
# -Sex
# -Smoker
# -Region

# %%
insurance_dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Analysis part 
#statistical mesaure of dataset

insurance_dataset.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#distribution of age value

sns.set()
plt.figure(figsize=(6,6))
sns.distplot(insurance_dataset['age'])
plt.title('Age Distribution')
plt.show()
# Out:
# c:\Users\Predator\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#for gender column

plt.figure(figsize=(5,5))
sns.countplot(x='sex',data=insurance_dataset)
plt.title('Sex distribution')
plt.show()

# %%
insurance_dataset['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
insurance_dataset['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.distplot(insurance_dataset['bmi'])
plt.title('BMI Distribution')
plt.show()
# Out:
# c:\Users\Predator\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Normal BMI Range ---->18.5 to 24.9
#IF < 18.5 = underweight
#If >24.9 =overweight

# %%
#Children

plt.figure(figsize=(6,6))
sns.countplot(x='children',data=insurance_dataset)
plt.title('Children')
plt.show()

# %%
insurance_dataset['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
#Smoker
plt.figure(figsize=(6,6))
sns.countplot(x='smoker',data=insurance_dataset)
plt.title('Smoker Distribution')
plt.show()

# %%
insurance_dataset['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
insurance_dataset['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
#Region
plt.figure(figsize=(6,6))
sns.countplot(x='region',data=insurance_dataset)
plt.title('Region Distribution')
plt.show()

# %%
#distribution of charges
plt.figure(figsize=(6,6))
sns.distplot(insurance_dataset['charges'])
plt.title('Charges Distribution')
plt.show()
# Out:
# c:\Users\Predator\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Data Pre-processing

# %%
#Encoding the categorical features

# %%
#For sex

insurance_dataset.replace({'sex':{'male':1,'female':0}},inplace=True)

#For smoker

insurance_dataset.replace({'smoker':{'yes':0,'no':1}},inplace=True)

#For reigon

insurance_dataset.replace({'region':{'southeast':0,'southwest':1,'northeast':2,'northwest':3}},inplace=True)

# %%
insurance_dataset
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       0       1  16884.92400
# 1      18    1  33.770         1       1       0   1725.55230
# 2      28    1  33.000         3       1       0   4449.46200
# 3      33    1  22.705         0       1       3  21984.47061
# 4      32    1  28.880         0       1       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       1       3  10600.54830
# 1334   18    0  31.920         0       1       2   2205.98080
# 1335   18    0  36.850         0       1       0   1629.83350
# 1336   21    0  25.800         0       1       1   2007.94500
# 1337   61    0  29.070         0       0       3  29141.36030
#
# [1338 rows x 7 columns]

# %%
#splitting the features and the target

# %%
X=insurance_dataset.drop(columns='charges',axis=1)
Y=insurance_dataset['charges']

# %%
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       0       1
# 1      18    1  33.770         1       1       0
# 2      28    1  33.000         3       1       0
# 3      33    1  22.705         0       1       3
# 4      32    1  28.880         0       1       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       1       3
# 1334   18    0  31.920         0       1       2
# 1335   18    0  36.850         0       1       0
# 1336   21    0  25.800         0       1       1
# 1337   61    0  29.070         0       0       3
#
# [1338 rows x 6 columns]

# %%
Y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
#Splitting the data into training data and testing data

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (1338, 6) (1070, 6) (268, 6)

# %%
#Model Training

# %% [markdown]
# LINEAR REGRESSION

# %%
regressor=LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#Model Evaluation
#prediction on training data

training_data_prediction=regressor.predict(X_train)

# %%
#R squared value

r2_train = metrics.r2_score(Y_train,training_data_prediction)
r2_train
# Out:
# 0.751505643411174

# %%
#prediction on testing data

test_data_prediction=regressor.predict(X_test)

# %%
#R squared value

r2_test= metrics.r2_score(Y_test,test_data_prediction)
r2_test
# Out:
# 0.7447273869684077

# %% [markdown]
# Building a Predictive System

# %%
input_data=(31,0,25.74,0,1,0)

#changing input data to numpy

input_data_as_numpy_array=np.array(input_data)

#reshape
input_data_reshape=input_data_as_numpy_array.reshape(1,-1)


prediction=regressor.predict(input_data_reshape)
# Out:
# c:\Users\Predator\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Insurance cost is:" , prediction[0])
# Out:
# Insurance cost is: 3760.080576496046

# %%
#decision tree

# %%
insurance_dataset
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       0       1  16884.92400
# 1      18    1  33.770         1       1       0   1725.55230
# 2      28    1  33.000         3       1       0   4449.46200
# 3      33    1  22.705         0       1       3  21984.47061
# 4      32    1  28.880         0       1       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       1       3  10600.54830
# 1334   18    0  31.920         0       1       2   2205.98080
# 1335   18    0  36.850         0       1       0   1629.83350
# 1336   21    0  25.800         0       1       1   2007.94500
# 1337   61    0  29.070         0       0       3  29141.36030
#
# [1338 rows x 7 columns]

# %%
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       0       1
# 1      18    1  33.770         1       1       0
# 2      28    1  33.000         3       1       0
# 3      33    1  22.705         0       1       3
# 4      32    1  28.880         0       1       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       1       3
# 1334   18    0  31.920         0       1       2
# 1335   18    0  36.850         0       1       0
# 1336   21    0  25.800         0       1       1
# 1337   61    0  29.070         0       0       3
#
# [1338 rows x 6 columns]

# %%
Y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor1 = DecisionTreeRegressor(random_state=0)
regressor1.fit(X_test,Y_test)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = regressor1.predict(X_test)
y_pred
# Out:
# array([ 2395.17155 , 11286.5387  ,  9617.66245 ,  1719.4363  ,
#         8891.1395  ,  5662.225   , 12609.88702 ,  2196.4732  ,
#        14254.6082  ,  7209.4918  , 12222.8983  ,  2219.4451  ,
#        19444.2658  ,  1121.8739  , 26392.26029 , 12925.886   ,
#         3645.0894  ,  5327.40025 , 18972.495   , 11774.159275,
#        11840.77505 ,  2597.779   , 40182.246   , 22331.5668  ,
#        37484.4493  , 10577.087   ,  3206.49135 ,  8944.1151  ,
#         3577.999   ,  3176.8159  ,  5397.6167  ,  3956.07145 ,
#         4931.647   ,  4239.89265 , 14478.33015 ,  1631.6683  ,
#        38792.6856  , 20420.60465 , 35147.52848 , 27000.98473 ,
#         2117.33885 , 34472.841   ,  7419.4779  ,  2007.945   ,
#         6781.3542  ,  5375.038   , 10264.4421  ,  3471.4096  ,
#   9566.9909    2250.8352    1748.774     3537.703     7281.5056
#   5594.8455    2689.4954   36219.40545  41661.602     4032.2407
#  34828.654    24059.68019   3556.9223    9304.7019    5488.262
#  43896.3763    7265.7025    9174.13565   7421.19455   1964.78
#   4149.736     4504.6624    1631.8212    9850.432    10231.4999
#  13887.9685    3857.75925  18648.4217    3353.4703   11658.37915
#  14901.5167   12928.7911    7441.053     3044.2133    4189.1131
#   7640.3092   15555.18875  17904.52705  14394.5579   16586.49771
#  40904.1995    9634.538    58571.07448  24873.3849   23045.56616
#   7623.518     4827.90495  11774.159275  7152.6714    6311.952
#   1769.53165   1632.03625  21472.4788    4433.9159    1146.7966
#  33750.2918    3268.84665   2464.6188    3201.24515  40720.55105
#   9855.1314    3392.3652    5920.1041   16657.71745   3490.5491
#  48675.5177   52590.82939  11879.10405  17043.3414    9722.7695
#  45863.205     6389.37785   2055.3249    2710.82855  14394.39815
#  11743.9341    2104.1134   41999.52      9563.029    27117.99378
#   1837.237    36950.2567    5458.04645   4500.33925  14256.1928
#  14692.66935  19199.944     1832.094    11482.63485   6457.8434
#  48517.56315   6799.458    42111.6647   15820.699    13429.0354
#  19521.9682    9432.9253    8211.1002   11033.6617    4449.462
#  11729.6795    3847.674     6238.298     2045.68525  23244.7902
#  55135.40209  11264.541     7371.772     1708.92575   6686.4313
#   9414.92      1727.54     11150.78      2302.3      24915.22085
#  22218.1149   12475.3513   16577.7795   10269.46      4005.4225
#   7160.094     2203.73595   6113.23105  10096.97     14235.072
#   3021.80915   6196.448     1702.4553    1694.7964    1253.936
#  18246.4955   39725.51805  44641.1974    1727.785    11566.30055
#  29141.3603    8978.1851   23967.38305 ]
# 99.5448367771426

# %%
import matplotlib.pyplot as plt
from sklearn import tree

# %%
plt.figure(figsize=(30,20))
tree.plot_tree(regressor1,rounded=True , filled=True)
plt.show()

# %%
# Create an instance of the DecisionTreeRegressor class
model1 = DecisionTreeRegressor()

# Fit the model to your data
model1.fit(X, Y)
# Out:
# DecisionTreeRegressor()

# %%
model1.score(X,Y)
# Out:
# 0.998667156135576

# %%
pred = model1.predict([[31,0,25.74,0,1,0]])

print('the cost is' , pred)
# Out:
#   File "C:\Users\Predator\AppData\Local\Temp\ipykernel_16544\106386371.py", line 3
#     the codt is pred
#         ^
# SyntaxError: invalid syntax

# %%
model1.predict([[19, 0, 27.900, 0, 0, 1]])
# Out:
# c:\Users\Predator\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([16884.924])

# %%
#plotting in graph

# %%
# from sklearn.tree import export_graphviz
# import graphviz

# # Export the decision tree as a Graphviz object
# dot_data = export_graphviz(model1, out_file=None, feature_names=X.columns)

# # Display the decision tree in Jupyter Notebook
# graphviz.Source(dot_data)

# %%
plt.figure(figsize=(20, 10))
# tree.plot_tree(model1, filled=True)
tree.plot_tree(model1, filled=True, feature_names=X.columns)
plt.show()

# %%
pickle.dump(insurance_dataset,open('insurance.pkl','wb'))
